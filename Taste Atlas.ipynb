# %%
from rdflib import Graph
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://localhost:7200/repositories/wikidata")

def gen():
    QUERY = '''
    PREFIX wd: <http://www.wikidata.org/entity/>
    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

    SELECT DISTINCT *
    WHERE {
        # ?food wdt:P279 wd:Q2095 .
        # ?food rdfs:label ?name .
        # ?food wdt:P5456 ?t .
        BIND(CONCAT("https://www.tasteatlas.com/", ?t) as ?taid) .
    }
    '''

    sparql.setQuery(QUERY)
    sparql.setReturnFormat(JSON)
    ret = sparql.queryAndConvert()

    for row in ret['results']['bindings']:
        yield {k: v['value'] for k, v in row.items()}


df = pd.DataFrame.from_records(gen())
df
# Out:
#                                           food             name  \
# 0      http://www.wikidata.org/entity/Q3596097     tomato sauce
# 1       http://www.wikidata.org/entity/Q134152         pan loaf
# 2      http://www.wikidata.org/entity/Q8193769            Imoni
# 3        http://www.wikidata.org/entity/Q12494       ladyfinger
# 4       http://www.wikidata.org/entity/Q145898  Zamorano cheese
# ...                                        ...              ...
# 1072  http://www.wikidata.org/entity/Q17098070       Honey dill
# 1073  http://www.wikidata.org/entity/Q17747240    Pleah sach ko
# 1074  http://www.wikidata.org/entity/Q41484834            Qedra
# 1075  http://www.wikidata.org/entity/Q43371176        Zoervleis
# 1076  http://www.wikidata.org/entity/Q62640531            Uraro
#
#                    t                                       taid
# 0       tomato-sauce    https://www.tasteatlas.com/tomato-sauce
# 1           shokupan        https://www.tasteatlas.com/shokupan
# 2              imoni           https://www.tasteatlas.com/imoni
# 3          savoiardi       https://www.tasteatlas.com/savoiardi
# 4     queso-zamorano  https://www.tasteatlas.com/queso-zamorano
# ...              ...                                        ...
# 1072      honey-dill      https://www.tasteatlas.com/honey-dill
# 1073   pleah-sach-ko   https://www.tasteatlas.com/pleah-sach-ko
# 1074          qidreh          https://www.tasteatlas.com/qidreh
# 1075       zoervleis       https://www.tasteatlas.com/zoervleis
# 1076           uraro           https://www.tasteatlas.com/uraro
#
# [1077 rows x 4 columns]

# %%
df.to_csv('food.csv')

# %%
import re
import json
import requests
from rdflib import Graph
from tqdm.notebook import tqdm
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
from requests_cache import CachedSession


retry_strategy = Retry(
    total=3,
    status_forcelist=[429, 500, 502, 503, 504],
    allowed_methods=["HEAD", "GET", "OPTIONS"]
)
adapter = HTTPAdapter(max_retries=retry_strategy)
http = CachedSession(backend='filesystem')
http.mount("https://", adapter)
http.mount("http://", adapter)

graph = {
    '@context': {
        '@vocab': 'https://www.tasteatlas.com/'
    },
    '@graph': []
}

for url in tqdm(set(df['taid'])):
    r = http.get(url, timeout=5)
    try:
        r.raise_for_status()
    except requests.HTTPError:
        continue
    m = re.search(r'window\.ta\.details = (\{.*\});', r.text)
    if m:
        data = json.loads(m[1])
        data['@id'] = url
        graph['@graph'].append(data)
    
g = Graph()
g.parse(data=json.dumps(graph), format='json-ld')
# Out:
#   0%|          | 0/1075 [00:00<?, ?it/s]
# <Graph identifier=N3414632b56dc4a15b3b4a0ce4949c790 (<class 'rdflib.graph.Graph'>)>

# %%
qres = g.query("""
prefix : <https://www.tasteatlas.com/>
prefix xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT
# ?taid ?name ?region ?pregion
(GROUP_CONCAT(DISTINCT ?ing; SEPARATOR="|") as ?ingredients)
WHERE {
    # ?taid :FoodIngredients ?i .
    # ?taid :Name ?name .
    # ?i :Name ?ing .
    # ?taid :Region ?r .
    # ?r :Current ?cr .
    # ?cr :Name ?region .
    # ?r :Parent ?pr .
    # ?pr :Name ?pregion .
}
GROUP BY ?taid ?name ?region ?pregion
""")

def gen():
    for row in qres:
        yield {k: str(v) for k, v in row.asdict().items()}

        
df2 = pd.DataFrame.from_records(gen())
df2
# Out:
#                                                   taid  \
# 0                    https://www.tasteatlas.com/lemang
# 1                 https://www.tasteatlas.com/muhammara
# 2    https://www.tasteatlas.com/khanom-farang-kutti...
# 3                  https://www.tasteatlas.com/flatbrod
# 4                    https://www.tasteatlas.com/zelnik
# ..                                                 ...
# 408                  https://www.tasteatlas.com/nimish
# 409           https://www.tasteatlas.com/chai-tow-kway
# 410              https://www.tasteatlas.com/ube-halaya
# 411         https://www.tasteatlas.com/kotlet-schabowy
# 412              https://www.tasteatlas.com/midye-tava
#
#                                   name           region   pregion  \
# 0                               Lemang        Indonesia      Asia
# 1                            Muhammara           Aleppo     Syria
# 2             Khanom farang kutti chin          Bangkok  Thailand
# 3                             Flatbrød           Norway    Europe
# 4                               Zelnik  North Macedonia    Europe
# ..                                 ...              ...       ...
# 408                             Nimish          Lucknow     India
# 409  Fried Carrot Cake (Chai tow kway)         Chaoshan     China
# 410                         Ube halaya      Philippines      Asia
# 411                    Kotlet schabowy           Poland    Europe
# 412                         Midye tava          Turkiye      Asia
#
#                                            ingredients
# 0                 Rice|Coconut Milk|Salt|Banana Leaves
# 1    Peppers|Olive Oil|Walnuts|Lemon Juice|Molasses...
# 2                   Duck Egg|Wheat Flour|Sugar|Raisins
# 3                                    Barley Flour|Salt
# 4    Flour|Eggs|Vinegar|Cheese|Spinach|Leek|Cabbage...
# ..                                                 ...
# 408  Milk|Heavy Cream|Cashews|Pistachios|Almonds|Su...
# 409       Turnip Cake|Eggs|Scallions|Salt|Black Pepper
# 410  Yam|Milk|Coconut Milk|Condensed Milk|Sugar|Van...
# 411  Pork|Flour|Eggs|Breadcrumbs|Black Pepper|Salt|...
# 412   Mussels|Flour|Eggs|Baking Soda|Black Pepper|Salt
#
# [413 rows x 5 columns]

# %%
df3 = df.merge(df2, on='taid')
set(df3['pregion'])
df3[df3['region'].isin(['England', 'Scotland', 'Wales'])]
# Out:
#                                          food                name_x  \
# 29    http://www.wikidata.org/entity/Q4383705           bread sauce
# 32    http://www.wikidata.org/entity/Q5054531    cauliflower cheese
# 39     http://www.wikidata.org/entity/Q209500                haggis
# 54   http://www.wikidata.org/entity/Q12411608   devils on horseback
# 58    http://www.wikidata.org/entity/Q1568296            Scotch egg
# 195   http://www.wikidata.org/entity/Q1219287            bara brith
# 305   http://www.wikidata.org/entity/Q5267373      Devilled kidneys
# 362   http://www.wikidata.org/entity/Q7354783             rock cake
# 395   http://www.wikidata.org/entity/Q5089394  Cheese and onion pie
#
#                         t                                             taid  \
# 29            bread-sauce           https://www.tasteatlas.com/bread-sauce
# 32     cauliflower-cheese    https://www.tasteatlas.com/cauliflower-cheese
# 39                 haggis                https://www.tasteatlas.com/haggis
# 54    devils-on-horseback   https://www.tasteatlas.com/devils-on-horseback
# 58             scotch-egg            https://www.tasteatlas.com/scotch-egg
# 195            bara-brith            https://www.tasteatlas.com/bara-brith
# 305      devilled-kidneys      https://www.tasteatlas.com/devilled-kidneys
# 362            rock-cakes            https://www.tasteatlas.com/rock-cakes
# 395  cheese-and-onion-pie  https://www.tasteatlas.com/cheese-and-onion-pie
#
#                    name_y    region pregion  \
# 29            Bread Sauce   England  Europe
# 32     Cauliflower Cheese   England  Europe
# 39                 Haggis  Scotland  Europe
# 54    Devils on Horseback   England  Europe
# 58            Scotch Eggs   England  Europe
# 195            Bara Brith     Wales  Europe
# 305      Devilled Kidneys   England  Europe
# 362            Rock Cakes   England  Europe
# 395  Cheese and Onion Pie   England  Europe
#
#                                            ingredients
# 29   Milk|Butter|Breadcrumbs|Onion|Clove|Nutmeg|Bay...
# 32        Cauliflower|Cheddar|Flour|Milk|Butter|Nutmeg
# 39   Offal|Onion|Oatmeal|Salt|Black Pepper|Thyme|Sa...
# 54                                 Bacon|Prune|Stilton
# 58     Eggs|Flour|Breadcrumbs|Sausage|Mustard|Salt|Oil
# 195  Flour|Sugar|Eggs|Orange|Honey|Tea|Candied Frui...
# 305  Offal|Worcestershire Sauce|Mustard|Vinegar|Cay...
# 362  Flour|Sugar|Eggs|Butter|Dried Fruit|Milk|Vanil...
# 395                    Cheddar|Onion|Flour|Butter|Eggs
